# %%
from pathlib import Path
import main

# %%
txt = main.read_file(Path("./corpora/bible.txt"))

# %%
freq, tokens = main.bpe(txt, 100, "w", normalize=True)
# Out:
# BPE Steps:   0%|          | 0/100 [00:00<?, ?it/s]INFO:root:BPE-Iteration 0
# BPE Steps:   1%|          | 1/100 [00:00<01:25,  1.15it/s]INFO:root:BPE-Iteration 1
# BPE Steps:   2%|▏         | 2/100 [00:01<01:23,  1.17it/s]INFO:root:BPE-Iteration 2
# BPE Steps:   3%|▎         | 3/100 [00:02<01:22,  1.18it/s]INFO:root:BPE-Iteration 3
# BPE Steps:   4%|▍         | 4/100 [00:03<01:20,  1.20it/s]INFO:root:BPE-Iteration 4
# BPE Steps:   5%|▌         | 5/100 [00:04<01:18,  1.21it/s]INFO:root:BPE-Iteration 5
# BPE Steps:   6%|▌         | 6/100 [00:04<01:17,  1.22it/s]INFO:root:BPE-Iteration 6
# BPE Steps:   7%|▋         | 7/100 [00:05<01:15,  1.23it/s]INFO:root:BPE-Iteration 7
# BPE Steps:   8%|▊         | 8/100 [00:06<01:13,  1.24it/s]INFO:root:BPE-Iteration 8
# BPE Steps:   9%|▉         | 9/100 [00:07<01:12,  1.25it/s]INFO:root:BPE-Iteration 9
# BPE Steps:  10%|█         | 10/100 [00:08<01:12,  1.24it/s]INFO:root:BPE-Iteration 10
# BPE Steps:  11%|█         | 11/100 [00:08<01:11,  1.25it/s]INFO:root:BPE-Iteration 11
# BPE Steps:  12%|█▏        | 12/100 [00:09<01:10,  1.26it/s]INFO:root:BPE-Iteration 12
# BPE Steps:  13%|█▎        | 13/100 [00:10<01:08,  1.26it/s]INFO:root:BPE-Iteration 13
# BPE Steps:  14%|█▍        | 14/100 [00:11<01:07,  1.28it/s]INFO:root:BPE-Iteration 14
# BPE Steps:  15%|█▌        | 15/100 [00:12<01:05,  1.29it/s]INFO:root:BPE-Iteration 15
# BPE Steps:  16%|█▌        | 16/100 [00:12<01:04,  1.30it/s]INFO:root:BPE-Iteration 16
# BPE Steps:  17%|█▋        | 17/100 [00:13<01:03,  1.30it/s]INFO:root:BPE-Iteration 17
# BPE Steps:  18%|█▊        | 18/100 [00:14<01:03,  1.30it/s]INFO:root:BPE-Iteration 18
# BPE Steps:  19%|█▉        | 19/100 [00:15<01:01,  1.32it/s]INFO:root:BPE-Iteration 19
# BPE Steps:  20%|██        | 20/100 [00:15<01:00,  1.33it/s]INFO:root:BPE-Iteration 20
# BPE Steps:  21%|██        | 21/100 [00:16<00:59,  1.33it/s]INFO:root:BPE-Iteration 21
# BPE Steps:  22%|██▏       | 22/100 [00:17<00:58,  1.34it/s]INFO:root:BPE-Iteration 22
# BPE Steps:  23%|██▎       | 23/100 [00:18<00:57,  1.35it/s]INFO:root:BPE-Iteration 23
# BPE Steps:  24%|██▍       | 24/100 [00:18<00:56,  1.36it/s]INFO:root:BPE-Iteration 24
# BPE Steps:  25%|██▌       | 25/100 [00:19<00:55,  1.36it/s]INFO:root:BPE-Iteration 25
# BPE Steps:  26%|██▌       | 26/100 [00:20<00:54,  1.36it/s]INFO:root:BPE-Iteration 26
# BPE Steps:  27%|██▋       | 27/100 [00:20<00:53,  1.36it/s]INFO:root:BPE-Iteration 27
# BPE Steps:  28%|██▊       | 28/100 [00:21<00:52,  1.37it/s]INFO:root:BPE-Iteration 28
# BPE Steps:  29%|██▉       | 29/100 [00:22<00:51,  1.37it/s]INFO:root:BPE-Iteration 29
# BPE Steps:  30%|███       | 30/100 [00:23<00:50,  1.38it/s]INFO:root:BPE-Iteration 30
# BPE Steps:  31%|███       | 31/100 [00:23<00:49,  1.38it/s]INFO:root:BPE-Iteration 31
# BPE Steps:  32%|███▏      | 32/100 [00:24<00:49,  1.38it/s]INFO:root:BPE-Iteration 32
# BPE Steps:  33%|███▎      | 33/100 [00:25<00:48,  1.38it/s]INFO:root:BPE-Iteration 33
# BPE Steps:  34%|███▍      | 34/100 [00:26<00:47,  1.39it/s]INFO:root:BPE-Iteration 34
# BPE Steps:  35%|███▌      | 35/100 [00:26<00:46,  1.39it/s]INFO:root:BPE-Iteration 35
# BPE Steps:  36%|███▌      | 36/100 [00:27<00:45,  1.40it/s]INFO:root:BPE-Iteration 36
# BPE Steps:  37%|███▋      | 37/100 [00:28<00:44,  1.40it/s]INFO:root:BPE-Iteration 37
# BPE Steps:  38%|███▊      | 38/100 [00:28<00:43,  1.42it/s]INFO:root:BPE-Iteration 38
# BPE Steps:  39%|███▉      | 39/100 [00:29<00:42,  1.42it/s]INFO:root:BPE-Iteration 39
# BPE Steps:  40%|████      | 40/100 [00:30<00:41,  1.43it/s]INFO:root:BPE-Iteration 40
# BPE Steps:  41%|████      | 41/100 [00:30<00:41,  1.44it/s]INFO:root:BPE-Iteration 41
# BPE Steps:  42%|████▏     | 42/100 [00:31<00:40,  1.44it/s]INFO:root:BPE-Iteration 42
# BPE Steps:  43%|████▎     | 43/100 [00:32<00:39,  1.45it/s]INFO:root:BPE-Iteration 43
# BPE Steps:  44%|████▍     | 44/100 [00:32<00:38,  1.45it/s]INFO:root:BPE-Iteration 44
# BPE Steps:  45%|████▌     | 45/100 [00:33<00:37,  1.46it/s]INFO:root:BPE-Iteration 45
# BPE Steps:  46%|████▌     | 46/100 [00:34<00:37,  1.45it/s]INFO:root:BPE-Iteration 46
# BPE Steps:  47%|████▋     | 47/100 [00:35<00:36,  1.46it/s]INFO:root:BPE-Iteration 47
# BPE Steps:  48%|████▊     | 48/100 [00:35<00:35,  1.47it/s]INFO:root:BPE-Iteration 48
# BPE Steps:  49%|████▉     | 49/100 [00:36<00:34,  1.47it/s]INFO:root:BPE-Iteration 49
# BPE Steps:  50%|█████     | 50/100 [00:37<00:33,  1.48it/s]INFO:root:BPE-Iteration 50
# BPE Steps:  51%|█████     | 51/100 [00:37<00:33,  1.48it/s]INFO:root:BPE-Iteration 51
# BPE Steps:  52%|█████▏    | 52/100 [00:38<00:32,  1.49it/s]INFO:root:BPE-Iteration 52
# BPE Steps:  53%|█████▎    | 53/100 [00:39<00:31,  1.49it/s]INFO:root:BPE-Iteration 53
# BPE Steps:  54%|█████▍    | 54/100 [00:39<00:30,  1.50it/s]INFO:root:BPE-Iteration 54
# BPE Steps:  55%|█████▌    | 55/100 [00:40<00:29,  1.51it/s]INFO:root:BPE-Iteration 55
# BPE Steps:  56%|█████▌    | 56/100 [00:41<00:29,  1.52it/s]INFO:root:BPE-Iteration 56
# BPE Steps:  57%|█████▋    | 57/100 [00:41<00:28,  1.53it/s]INFO:root:BPE-Iteration 57
# BPE Steps:  58%|█████▊    | 58/100 [00:42<00:27,  1.53it/s]INFO:root:BPE-Iteration 58
# BPE Steps:  59%|█████▉    | 59/100 [00:42<00:26,  1.54it/s]INFO:root:BPE-Iteration 59
# BPE Steps:  60%|██████    | 60/100 [00:43<00:26,  1.52it/s]INFO:root:BPE-Iteration 60
# BPE Steps:  61%|██████    | 61/100 [00:44<00:25,  1.54it/s]INFO:root:BPE-Iteration 61
# BPE Steps:  62%|██████▏   | 62/100 [00:44<00:24,  1.54it/s]INFO:root:BPE-Iteration 62
# BPE Steps:  63%|██████▎   | 63/100 [00:45<00:23,  1.55it/s]INFO:root:BPE-Iteration 63
# BPE Steps:  64%|██████▍   | 64/100 [00:46<00:23,  1.56it/s]INFO:root:BPE-Iteration 64
# BPE Steps:  65%|██████▌   | 65/100 [00:46<00:22,  1.56it/s]INFO:root:BPE-Iteration 65
# BPE Steps:  66%|██████▌   | 66/100 [00:47<00:21,  1.57it/s]INFO:root:BPE-Iteration 66
# BPE Steps:  67%|██████▋   | 67/100 [00:48<00:20,  1.58it/s]INFO:root:BPE-Iteration 67
# BPE Steps:  68%|██████▊   | 68/100 [00:48<00:20,  1.58it/s]INFO:root:BPE-Iteration 68
# BPE Steps:  69%|██████▉   | 69/100 [00:49<00:19,  1.58it/s]INFO:root:BPE-Iteration 69
# BPE Steps:  70%|███████   | 70/100 [00:49<00:18,  1.59it/s]INFO:root:BPE-Iteration 70
# BPE Steps:  71%|███████   | 71/100 [00:50<00:18,  1.59it/s]INFO:root:BPE-Iteration 71
# BPE Steps:  72%|███████▏  | 72/100 [00:51<00:17,  1.58it/s]INFO:root:BPE-Iteration 72
# BPE Steps:  73%|███████▎  | 73/100 [00:51<00:17,  1.59it/s]INFO:root:BPE-Iteration 73
# BPE Steps:  74%|███████▍  | 74/100 [00:52<00:16,  1.60it/s]INFO:root:BPE-Iteration 74
# BPE Steps:  75%|███████▌  | 75/100 [00:53<00:15,  1.61it/s]INFO:root:BPE-Iteration 75
# BPE Steps:  76%|███████▌  | 76/100 [00:53<00:14,  1.61it/s]INFO:root:BPE-Iteration 76
# BPE Steps:  77%|███████▋  | 77/100 [00:54<00:14,  1.61it/s]INFO:root:BPE-Iteration 77
# BPE Steps:  78%|███████▊  | 78/100 [00:54<00:13,  1.61it/s]INFO:root:BPE-Iteration 78
# BPE Steps:  79%|███████▉  | 79/100 [00:55<00:13,  1.61it/s]INFO:root:BPE-Iteration 79
# BPE Steps:  80%|████████  | 80/100 [00:56<00:12,  1.62it/s]INFO:root:BPE-Iteration 80
# BPE Steps:  81%|████████  | 81/100 [00:56<00:11,  1.62it/s]INFO:root:BPE-Iteration 81
# BPE Steps:  82%|████████▏ | 82/100 [00:57<00:11,  1.62it/s]INFO:root:BPE-Iteration 82
# BPE Steps:  83%|████████▎ | 83/100 [00:57<00:10,  1.62it/s]INFO:root:BPE-Iteration 83
# BPE Steps:  84%|████████▍ | 84/100 [00:58<00:09,  1.63it/s]INFO:root:BPE-Iteration 84
# BPE Steps:  85%|████████▌ | 85/100 [00:59<00:09,  1.63it/s]INFO:root:BPE-Iteration 85
# BPE Steps:  86%|████████▌ | 86/100 [00:59<00:08,  1.63it/s]INFO:root:BPE-Iteration 86
# BPE Steps:  87%|████████▋ | 87/100 [01:00<00:07,  1.64it/s]INFO:root:BPE-Iteration 87
# BPE Steps:  88%|████████▊ | 88/100 [01:01<00:07,  1.64it/s]INFO:root:BPE-Iteration 88
# BPE Steps:  89%|████████▉ | 89/100 [01:01<00:06,  1.64it/s]INFO:root:BPE-Iteration 89
# BPE Steps:  90%|█████████ | 90/100 [01:02<00:06,  1.64it/s]INFO:root:BPE-Iteration 90
# BPE Steps:  91%|█████████ | 91/100 [01:02<00:05,  1.64it/s]INFO:root:BPE-Iteration 91
# BPE Steps:  92%|█████████▏| 92/100 [01:03<00:04,  1.63it/s]INFO:root:BPE-Iteration 92
# BPE Steps:  93%|█████████▎| 93/100 [01:04<00:04,  1.64it/s]INFO:root:BPE-Iteration 93
# BPE Steps:  94%|█████████▍| 94/100 [01:04<00:03,  1.65it/s]INFO:root:BPE-Iteration 94
# BPE Steps:  95%|█████████▌| 95/100 [01:05<00:03,  1.66it/s]INFO:root:BPE-Iteration 95
# BPE Steps:  96%|█████████▌| 96/100 [01:05<00:02,  1.66it/s]INFO:root:BPE-Iteration 96
# BPE Steps:  97%|█████████▋| 97/100 [01:06<00:01,  1.67it/s]INFO:root:BPE-Iteration 97
# BPE Steps:  98%|█████████▊| 98/100 [01:07<00:01,  1.67it/s]INFO:root:BPE-Iteration 98
# BPE Steps:  99%|█████████▉| 99/100 [01:07<00:00,  1.69it/s]INFO:root:BPE-Iteration 99
# BPE Steps: 100%|██████████| 100/100 [01:08<00:00,  1.47it/s]

# %%
freq
# Out:
# [('▁', 824036),
#  ('the', 76309),
#  (',', 63207),
#  ('s', 62295),
#  ('and', 58269),
#  ('a', 52806),
#  ('t', 50525),
#  ('e', 49204),
#  ('d', 41888),
#  ('i', 41826),
#  ('o', 38600),
#  ('of', 38178),
#  ('c', 35112),
#  ('f', 34170),
#  ('m', 34001),
#  ('l', 33772),
#  ('p', 32800),
#  ('w', 30755),
#  ('n', 30476),
#  ('y', 28890),
#  ('th', 27650),
#  ('u', 27250),
#  ('in', 26641),
#  ('re', 26468),
#  ('.', 26417),
#  (':', 25402),
#  ('he', 24156),
#  ('b', 23424),
#  ('g', 22937),
#  ('r', 22755),
#  ('on', 21266),
#  ('es', 20962),
#  ('to', 19557),
#  ('is', 19291),
#  ('er', 19030),
#  ('an', 18384),
#  ('ed', 17948),
#  ('h', 17492),
#  ('k', 16730),
#  ('be', 16689),
#  ('ing', 15975),
#  ('1', 15923),
#  ('ha', 15708),
#  ('ar', 15352),
#  ('ou', 15331),
#  ('it', 14743),
#  ('se', 14657),
#  ('me', 13209),
#  ('that', 12929),
#  ('sa', 12598),
#  ('3', 12259),
#  ('le', 12053),
#  ('2', 11719),
#  ('as', 11322),
#  ('en', 11300),
#  ('for', 11186),
#  (':1', 11164),
#  ('at', 10901),
#  ('v', 10544),
#  ('st', 10338),
#  (';', 10139),
#  ('shall', 9869),
#  ('ve', 9750),
#  ('id', 9437),
#  ('4', 9150),
#  ('om', 9081),
#  ('unto', 9036),
#  ('j', 8880),
#  ('ld', 8612),
#  ('his', 8610),
#  ('ll', 8228),
#  ('lord', 8009),
#  ('or', 7994),
#  ('all', 7747),
#  ('we', 7673),
#  ('s,', 7508),
#  ('they', 7379),
#  ('him', 7271),
#  (':2', 7257),
#  ('ra', 7212),
#  ('5', 7053),
#  ('with', 6984),
#  ('ir', 6856),
#  ('not', 6856),
#  ('them', 6840),
#  ('ce', 6569),
#  ('ay', 6527),
#  ('ho', 6479),
#  ('6', 6472),
#  ('thou', 6444),
#  ('ye', 6090),
#  ('li', 6039),
#  ('ri', 6027),
#  ('ver', 5973),
#  ('ght', 5926),
#  ('7', 5917),
#  ('de', 5906),
#  ('wi', 5827),
#  ('ther', 5819),
#  ('ent', 5807),
#  ('8', 5778),
#  ('up', 5755),
#  ('9', 5641),
#  ('ke', 5551),
#  ('al', 5500),
#  ('so', 5391),
#  ('our', 5385),
#  ('0', 5318),
#  ('ca', 5310),
#  ('there', 5166),
#  ('hi', 5006),
#  ('thy', 4928),
#  ('ro', 4864),
#  ('was', 4835),
#  ('no', 4824),
#  ('god', 4787),
#  ('am', 4773),
#  ('my', 4754),
#  ('pe', 4693),
#  ('ab', 4626),
#  ('ore', 4606),
#  ('whe', 4477),
#  ('which', 4420),
#  ('are', 4369),
#  ('ain', 4343),
#  ('el', 4246),
#  ('out', 4164),
#  ('ion', 4123),
#  ('but', 4114),
#  ('ven', 4095),
#  ('go', 3752),
#  ('ch', 3645),
#  ('un', 3631),
#  ('?', 3297),
#  ('ord', 3230),
#  ('z', 2972),
#  ('ut', 2352),
#  ('sha', 2321),
#  ("'", 2024),
#  ('gh', 1902),
#  ('x', 1478),
#  ('q', 964),
#  ('whi', 507),
#  ('!', 314),
#  ('(', 241),
#  (')', 241),
#  ('-', 97),
#  ('*', 25),
#  ('/', 24),
#  ('"', 22),
#  ('@', 2),
#  ('$', 2),
#  ('%', 1)]

# %%
tokens
# Out:
# ['▁',
#  '1',
#  ':1',
#  '▁',
#  'in',
#  '▁',
#  'the',
#  '▁',
#  'be',
#  'g',
#  'in',
#  'n',
#  'ing',
#  '▁',
#  'god',
#  '▁',
#  'c',
#  're',
#  'at',
#  'ed',
#  '▁',
#  'the',
#  '▁',
#  'he',
#  'a',
#  'ven',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ar',
#  'th',
#  '.',
#  '▁',
#  '1',
#  ':2',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ar',
#  'th',
#  '▁',
#  'was',
#  '▁',
#  'with',
#  'out',
#  '▁',
#  'for',
#  'm',
#  ',',
#  '▁',
#  'and',
#  '▁',
#  'v',
#  'o',
#  'id',
#  ';',
#  '▁',
#  'and',
#  '▁',
#  'd',
#  'ar',
#  'k',
#  'n',
#  'es',
#  's',
#  '▁',
#  'was',
#  '▁',
#  'up',
#  'on',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'a',
#  'ce',
#  '▁',
#  'of',
#  '▁',
#  'the',
#  '▁',
#  'de',
#  'e',
#  'p',
#  '.',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  's',
#  'p',
#  'ir',
#  'it',
#  '▁',
#  'of',
#  '▁',
#  'god',
#  '▁',
#  'm',
#  'o',
#  'v',
#  'ed',
#  '▁',
#  'up',
#  'on',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'a',
#  'ce',
#  '▁',
#  'of',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's',
#  '.',
#  '▁',
#  '1',
#  ':',
#  '3',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'id',
#  ',',
#  '▁',
#  'le',
#  't',
#  '▁',
#  'there',
#  '▁',
#  'be',
#  '▁',
#  'li',
#  'ght',
#  ':',
#  '▁',
#  'and',
#  '▁',
#  'there',
#  '▁',
#  'was',
#  '▁',
#  'li',
#  'ght',
#  '.',
#  '▁',
#  '1',
#  ':',
#  '4',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'w',
#  '▁',
#  'the',
#  '▁',
#  'li',
#  'ght',
#  ',',
#  '▁',
#  'that',
#  '▁',
#  'it',
#  '▁',
#  'was',
#  '▁',
#  'go',
#  'o',
#  'd',
#  ':',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'd',
#  'i',
#  'v',
#  'id',
#  'ed',
#  '▁',
#  'the',
#  '▁',
#  'li',
#  'ght',
#  '▁',
#  'f',
#  'r',
#  'om',
#  '▁',
#  'the',
#  '▁',
#  'd',
#  'ar',
#  'k',
#  'n',
#  'es',
#  's',
#  '.',
#  '▁',
#  '1',
#  ':',
#  '5',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'c',
#  'all',
#  'ed',
#  '▁',
#  'the',
#  '▁',
#  'li',
#  'ght',
#  '▁',
#  'd',
#  'ay',
#  ',',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'd',
#  'ar',
#  'k',
#  'n',
#  'es',
#  's',
#  '▁',
#  'he',
#  '▁',
#  'c',
#  'all',
#  'ed',
#  '▁',
#  'n',
#  'i',
#  'ght',
#  '.',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ven',
#  'ing',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'm',
#  'or',
#  'n',
#  'ing',
#  '▁',
#  'we',
#  're',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'ir',
#  'st',
#  '▁',
#  'd',
#  'ay',
#  '.',
#  '▁',
#  '1',
#  ':',
#  '6',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'id',
#  ',',
#  '▁',
#  'le',
#  't',
#  '▁',
#  'there',
#  '▁',
#  'be',
#  '▁',
#  'a',
#  '▁',
#  'f',
#  'ir',
#  'm',
#  'am',
#  'ent',
#  '▁',
#  'in',
#  '▁',
#  'the',
#  '▁',
#  'm',
#  'id',
#  'st',
#  '▁',
#  'of',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's,',
#  '▁',
#  'and',
#  '▁',
#  'le',
#  't',
#  '▁',
#  'it',
#  '▁',
#  'd',
#  'i',
#  'v',
#  'id',
#  'e',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's',
#  '▁',
#  'f',
#  'r',
#  'om',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's',
#  '.',
#  '▁',
#  '1',
#  ':',
#  '7',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'm',
#  'a',
#  'de',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'ir',
#  'm',
#  'am',
#  'ent',
#  ',',
#  '▁',
#  'and',
#  '▁',
#  'd',
#  'i',
#  'v',
#  'id',
#  'ed',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's',
#  '▁',
#  'which',
#  '▁',
#  'we',
#  're',
#  '▁',
#  'un',
#  'd',
#  'er',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'ir',
#  'm',
#  'am',
#  'ent',
#  '▁',
#  'f',
#  'r',
#  'om',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's',
#  '▁',
#  'which',
#  '▁',
#  'we',
#  're',
#  '▁',
#  'ab',
#  'o',
#  've',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'ir',
#  'm',
#  'am',
#  'ent',
#  ':',
#  '▁',
#  'and',
#  '▁',
#  'it',
#  '▁',
#  'was',
#  '▁',
#  'so',
#  '.',
#  '▁',
#  '1',
#  ':',
#  '8',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'c',
#  'all',
#  'ed',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'ir',
#  'm',
#  'am',
#  'ent',
#  '▁',
#  'he',
#  'a',
#  'ven',
#  '.',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ven',
#  'ing',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'm',
#  'or',
#  'n',
#  'ing',
#  '▁',
#  'we',
#  're',
#  '▁',
#  'the',
#  '▁',
#  'se',
#  'c',
#  'on',
#  'd',
#  '▁',
#  'd',
#  'ay',
#  '.',
#  '▁',
#  '1',
#  ':',
#  '9',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'id',
#  ',',
#  '▁',
#  'le',
#  't',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's',
#  '▁',
#  'un',
#  'd',
#  'er',
#  '▁',
#  'the',
#  '▁',
#  'he',
#  'a',
#  'ven',
#  '▁',
#  'be',
#  '▁',
#  'g',
#  'a',
#  'there',
#  'd',
#  '▁',
#  'to',
#  'g',
#  'e',
#  'ther',
#  '▁',
#  'unto',
#  '▁',
#  'on',
#  'e',
#  '▁',
#  'p',
#  'l',
#  'a',
#  'ce',
#  ',',
#  '▁',
#  'and',
#  '▁',
#  'le',
#  't',
#  '▁',
#  'the',
#  '▁',
#  'd',
#  'r',
#  'y',
#  '▁',
#  'l',
#  'and',
#  '▁',
#  'a',
#  'p',
#  'pe',
#  'ar',
#  ':',
#  '▁',
#  'and',
#  '▁',
#  'it',
#  '▁',
#  'was',
#  '▁',
#  'so',
#  '.',
#  '▁',
#  '1',
#  ':1',
#  '0',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'c',
#  'all',
#  'ed',
#  '▁',
#  'the',
#  '▁',
#  'd',
#  'r',
#  'y',
#  '▁',
#  'l',
#  'and',
#  '▁',
#  'e',
#  'ar',
#  'th',
#  ';',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'g',
#  'a',
#  'ther',
#  'ing',
#  '▁',
#  'to',
#  'g',
#  'e',
#  'ther',
#  '▁',
#  'of',
#  '▁',
#  'the',
#  '▁',
#  'w',
#  'at',
#  'er',
#  's',
#  '▁',
#  'c',
#  'all',
#  'ed',
#  '▁',
#  'he',
#  '▁',
#  'se',
#  'as',
#  ':',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'w',
#  '▁',
#  'that',
#  '▁',
#  'it',
#  '▁',
#  'was',
#  '▁',
#  'go',
#  'o',
#  'd',
#  '.',
#  '▁',
#  '1',
#  ':1',
#  '1',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'id',
#  ',',
#  '▁',
#  'le',
#  't',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ar',
#  'th',
#  '▁',
#  'b',
#  'r',
#  'ing',
#  '▁',
#  'for',
#  'th',
#  '▁',
#  'g',
#  'r',
#  'as',
#  's,',
#  '▁',
#  'the',
#  '▁',
#  'he',
#  'r',
#  'b',
#  '▁',
#  'y',
#  'i',
#  'e',
#  'ld',
#  'ing',
#  '▁',
#  'se',
#  'ed',
#  ',',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'r',
#  'u',
#  'it',
#  '▁',
#  't',
#  're',
#  'e',
#  '▁',
#  'y',
#  'i',
#  'e',
#  'ld',
#  'ing',
#  '▁',
#  'f',
#  'r',
#  'u',
#  'it',
#  '▁',
#  'a',
#  'f',
#  't',
#  'er',
#  '▁',
#  'his',
#  '▁',
#  'k',
#  'in',
#  'd',
#  ',',
#  '▁',
#  'w',
#  'ho',
#  'se',
#  '▁',
#  'se',
#  'ed',
#  '▁',
#  'is',
#  '▁',
#  'in',
#  '▁',
#  'it',
#  'se',
#  'l',
#  'f',
#  ',',
#  '▁',
#  'up',
#  'on',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ar',
#  'th',
#  ':',
#  '▁',
#  'and',
#  '▁',
#  'it',
#  '▁',
#  'was',
#  '▁',
#  'so',
#  '.',
#  '▁',
#  '1',
#  ':1',
#  '2',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ar',
#  'th',
#  '▁',
#  'b',
#  'r',
#  'ou',
#  'ght',
#  '▁',
#  'for',
#  'th',
#  '▁',
#  'g',
#  'r',
#  'as',
#  's,',
#  '▁',
#  'and',
#  '▁',
#  'he',
#  'r',
#  'b',
#  '▁',
#  'y',
#  'i',
#  'e',
#  'ld',
#  'ing',
#  '▁',
#  'se',
#  'ed',
#  '▁',
#  'a',
#  'f',
#  't',
#  'er',
#  '▁',
#  'his',
#  '▁',
#  'k',
#  'in',
#  'd',
#  ',',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  't',
#  're',
#  'e',
#  '▁',
#  'y',
#  'i',
#  'e',
#  'ld',
#  'ing',
#  '▁',
#  'f',
#  'r',
#  'u',
#  'it',
#  ',',
#  '▁',
#  'w',
#  'ho',
#  'se',
#  '▁',
#  'se',
#  'ed',
#  '▁',
#  'was',
#  '▁',
#  'in',
#  '▁',
#  'it',
#  'se',
#  'l',
#  'f',
#  ',',
#  '▁',
#  'a',
#  'f',
#  't',
#  'er',
#  '▁',
#  'his',
#  '▁',
#  'k',
#  'in',
#  'd',
#  ':',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'w',
#  '▁',
#  'that',
#  '▁',
#  'it',
#  '▁',
#  'was',
#  '▁',
#  'go',
#  'o',
#  'd',
#  '.',
#  '▁',
#  '1',
#  ':1',
#  '3',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'e',
#  'ven',
#  'ing',
#  '▁',
#  'and',
#  '▁',
#  'the',
#  '▁',
#  'm',
#  'or',
#  'n',
#  'ing',
#  '▁',
#  'we',
#  're',
#  '▁',
#  'the',
#  '▁',
#  'th',
#  'ir',
#  'd',
#  '▁',
#  'd',
#  'ay',
#  '.',
#  '▁',
#  '1',
#  ':1',
#  '4',
#  '▁',
#  'and',
#  '▁',
#  'god',
#  '▁',
#  'sa',
#  'id',
#  ',',
#  '▁',
#  'le',
#  't',
#  '▁',
#  'there',
#  '▁',
#  'be',
#  '▁',
#  'li',
#  'ght',
#  's',
#  '▁',
#  'in',
#  '▁',
#  'the',
#  '▁',
#  'f',
#  'ir',
#  'm',
#  'am',
#  'ent',
#  '▁',
#  'of',
#  '▁',
#  'the',
#  '▁',
#  'he',
#  'a',
#  'ven',
#  '▁',
#  'to',
#  '▁',
#  'd',
#  'i',
#  'v',
#  'id',
#  'e',
#  '▁',
#  'the',
#  ...]

# %%
[t for t in freq if len(t[0]) > 1]
# Out:
# [('the', 76309),
#  ('and', 58269),
#  ('of', 38178),
#  ('th', 27650),
#  ('in', 26641),
#  ('re', 26468),
#  ('he', 24156),
#  ('on', 21266),
#  ('es', 20962),
#  ('to', 19557),
#  ('is', 19291),
#  ('er', 19030),
#  ('an', 18384),
#  ('ed', 17948),
#  ('be', 16689),
#  ('ing', 15975),
#  ('ha', 15708),
#  ('ar', 15352),
#  ('ou', 15331),
#  ('it', 14743),
#  ('se', 14657),
#  ('me', 13209),
#  ('that', 12929),
#  ('sa', 12598),
#  ('le', 12053),
#  ('as', 11322),
#  ('en', 11300),
#  ('for', 11186),
#  (':1', 11164),
#  ('at', 10901),
#  ('st', 10338),
#  ('shall', 9869),
#  ('ve', 9750),
#  ('id', 9437),
#  ('om', 9081),
#  ('unto', 9036),
#  ('ld', 8612),
#  ('his', 8610),
#  ('ll', 8228),
#  ('lord', 8009),
#  ('or', 7994),
#  ('all', 7747),
#  ('we', 7673),
#  ('s,', 7508),
#  ('they', 7379),
#  ('him', 7271),
#  (':2', 7257),
#  ('ra', 7212),
#  ('with', 6984),
#  ('ir', 6856),
#  ('not', 6856),
#  ('them', 6840),
#  ('ce', 6569),
#  ('ay', 6527),
#  ('ho', 6479),
#  ('thou', 6444),
#  ('ye', 6090),
#  ('li', 6039),
#  ('ri', 6027),
#  ('ver', 5973),
#  ('ght', 5926),
#  ('de', 5906),
#  ('wi', 5827),
#  ('ther', 5819),
#  ('ent', 5807),
#  ('up', 5755),
#  ('ke', 5551),
#  ('al', 5500),
#  ('so', 5391),
#  ('our', 5385),
#  ('ca', 5310),
#  ('there', 5166),
#  ('hi', 5006),
#  ('thy', 4928),
#  ('ro', 4864),
#  ('was', 4835),
#  ('no', 4824),
#  ('god', 4787),
#  ('am', 4773),
#  ('my', 4754),
#  ('pe', 4693),
#  ('ab', 4626),
#  ('ore', 4606),
#  ('whe', 4477),
#  ('which', 4420),
#  ('are', 4369),
#  ('ain', 4343),
#  ('el', 4246),
#  ('out', 4164),
#  ('ion', 4123),
#  ('but', 4114),
#  ('ven', 4095),
#  ('go', 3752),
#  ('ch', 3645),
#  ('un', 3631),
#  ('ord', 3230),
#  ('ut', 2352),
#  ('sha', 2321),
#  ('gh', 1902),
#  ('whi', 507)]
