# %%
from pathlib import Path
import main

# %%
txt = main.read_file(Path("./corpora/song.txt"))

# %%
freq, tokens = main.bpe(txt, 100, "w", normalize=True)
# Out:
# BPE Steps:   0%|          | 0/100 [00:00<?, ?it/s]INFO:root:BPE-Iteration 0
# INFO:root:BPE-Iteration 1
# INFO:root:BPE-Iteration 2
# INFO:root:BPE-Iteration 3
# INFO:root:BPE-Iteration 4
# INFO:root:BPE-Iteration 5
# INFO:root:BPE-Iteration 6
# INFO:root:BPE-Iteration 7
# INFO:root:BPE-Iteration 8
# INFO:root:BPE-Iteration 9
# INFO:root:BPE-Iteration 10
# INFO:root:BPE-Iteration 11
# INFO:root:BPE-Iteration 12
# INFO:root:BPE-Iteration 13
# INFO:root:BPE-Iteration 14
# INFO:root:BPE-Iteration 15
# INFO:root:BPE-Iteration 16
# INFO:root:BPE-Iteration 17
# INFO:root:BPE-Iteration 18
# INFO:root:BPE-Iteration 19
# INFO:root:BPE-Iteration 20
# INFO:root:BPE-Iteration 21
# INFO:root:BPE-Iteration 22
# INFO:root:BPE-Iteration 23
# INFO:root:BPE-Iteration 24
# INFO:root:BPE-Iteration 25
# INFO:root:BPE-Iteration 26
# INFO:root:BPE-Iteration 27
# INFO:root:BPE-Iteration 28
# INFO:root:BPE-Iteration 29
# INFO:root:BPE-Iteration 30
# INFO:root:BPE-Iteration 31
# INFO:root:BPE-Iteration 32
# ...

# %%
freq
# Out:
# [('▁', 106),
#  ("you'll", 8),
#  ('be', 8),
#  ('hackers,', 8),
#  ('the', 6),
#  ('t', 5),
#  ('join', 4),
#  ('us', 4),
#  ('now', 4),
#  ('and', 4),
#  ('share', 4),
#  ('software;', 4),
#  ('free,', 4),
#  ('free.', 4),
#  ('i', 4),
#  (',', 4),
#  ('e', 3),
#  ('l', 3),
#  ('y', 3),
#  ('.', 3),
#  ('not', 3),
#  ('s', 3),
#  ('ho', 2),
#  ('r', 2),
#  ('d', 2),
#  ('can', 2),
#  ('p', 2),
#  ('es', 2),
#  ('ne', 2),
#  ('that', 2),
#  ('is', 2),
#  ('true', 2),
#  ('b', 2),
#  ('he', 2),
#  ('ir', 2),
#  ('gh', 2),
#  ("that's", 2),
#  ('good', 2),
#  ('we', 2),
#  ('en', 2),
#  ('ou', 2),
#  ('at', 2),
#  ('our', 2),
#  ('call,', 2),
#  ('ever', 2),
#  ('more', 2),
#  ('a', 1),
#  ('ers', 1),
#  ('g', 1),
#  ('of', 1),
#  ('mo', 1),
#  ('u', 1),
#  ('o', 1),
#  (';', 1),
#  ('w', 1),
#  ('n', 1),
#  ('ha', 1),
#  ('v', 1),
#  ('free', 1),
#  ('software', 1),
#  ("'ll", 1),
#  ('k', 1),
#  ('ck', 1),
#  ('c', 1)]

# %%
tokens
# Out:
# ['▁',
#  'join',
#  '▁',
#  'us',
#  '▁',
#  'now',
#  '▁',
#  'and',
#  '▁',
#  'share',
#  '▁',
#  'the',
#  '▁',
#  'software;',
#  '▁',
#  "you'll",
#  '▁',
#  'be',
#  '▁',
#  'free,',
#  '▁',
#  'hackers,',
#  '▁',
#  "you'll",
#  '▁',
#  'be',
#  '▁',
#  'free.',
#  '▁',
#  'join',
#  '▁',
#  'us',
#  '▁',
#  'now',
#  '▁',
#  'and',
#  '▁',
#  'share',
#  '▁',
#  'the',
#  '▁',
#  'software;',
#  '▁',
#  "you'll",
#  '▁',
#  'be',
#  '▁',
#  'free,',
#  '▁',
#  'hackers,',
#  '▁',
#  "you'll",
#  '▁',
#  'be',
#  '▁',
#  'free.',
#  '▁',
#  'ho',
#  'a',
#  'r',
#  'd',
#  'ers',
#  '▁',
#  'can',
#  '▁',
#  'g',
#  'e',
#  't',
#  '▁',
#  'p',
#  'i',
#  'l',
#  'es',
#  '▁',
#  'of',
#  '▁',
#  'mo',
#  'ne',
#  'y',
#  ',',
#  '▁',
#  'that',
#  '▁',
#  'is',
#  '▁',
#  'true',
#  ',',
#  '▁',
#  'hackers,',
#  '▁',
#  'that',
#  '▁',
#  'is',
#  '▁',
#  'true',
#  '.',
#  '▁',
#  'b',
#  'u',
#  't',
#  '▁',
#  'the',
#  'y',
#  '▁',
#  'can',
#  'not',
#  '▁',
#  'he',
# ...

# %%
[t for t in freq if len(t[0]) > 1]
# Out:
# [("you'll", 8),
#  ('be', 8),
#  ('hackers,', 8),
#  ('the', 6),
#  ('join', 4),
#  ('us', 4),
#  ('now', 4),
#  ('and', 4),
#  ('share', 4),
#  ('software;', 4),
#  ('free,', 4),
#  ('free.', 4),
#  ('not', 3),
#  ('ho', 2),
#  ('can', 2),
#  ('es', 2),
#  ('ne', 2),
#  ('that', 2),
#  ('is', 2),
#  ('true', 2),
#  ('he', 2),
#  ('ir', 2),
#  ('gh', 2),
#  ("that's", 2),
#  ('good', 2),
#  ('we', 2),
#  ('en', 2),
#  ('ou', 2),
#  ('at', 2),
#  ('our', 2),
#  ('call,', 2),
#  ('ever', 2),
#  ('more', 2),
#  ('ers', 1),
#  ('of', 1),
#  ('mo', 1),
#  ('ha', 1),
#  ('free', 1),
#  ('software', 1),
#  ("'ll", 1),
#  ('ck', 1)]
