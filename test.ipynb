# %%
from pathlib import Path
import main

# %%
txt = main.read_file(Path("./corpora/sherlock.txt"))

# %%
freq, tokens = main.bpe(txt, 100_000, "w", normalize=True)
# Out:
# BPE Steps:   6%|▋         | 63/1000 [12:05<2:59:54, 11.52s/100 steps]

# %%
main.write_output(Path.cwd() / "output/sherlock", freq, tokens)
# Out:
# WARNING:root:Directory /Users/roman/Repos/bpe_tokenizer/output/sherlock already exists. Overwriting files.
# INFO:root:Frequency table written to /Users/roman/Repos/bpe_tokenizer/output/sherlock/freq_table.txt
# INFO:root:Tokens written to /Users/roman/Repos/bpe_tokenizer/output/sherlock/tokens.txt

# %%
freq
# Out:
# [('▁the', 2493),
#  ('▁and', 1312),
#  ('▁of', 1209),
#  ('▁to', 1093),
#  ('▁a', 998),
#  ('▁i', 778),
#  ('▁he', 770),
#  ('▁in', 719),
#  ('▁his', 645),
#  ('▁was', 639),
#  ('▁that', 610),
#  ('▁had', 470),
#  ('▁it', 405),
#  ('▁you', 352),
#  ('▁with', 335),
#  ('▁as', 333),
#  ('▁at', 316),
#  ('▁which', 312),
#  (',', 311),
#  ('▁for', 305),
#  ('▁my', 293),
#  ('.', 287),
#  ('▁have', 282),
#  ('▁is', 282),
#  ('▁be', 249),
#  ('▁on', 217),
#  ('▁there', 204),
#  ('▁upon', 197),
#  ('▁this', 194),
#  ('▁from', 183),
#  ('▁not', 180),
#  ('▁they', 173),
#  ('▁but', 172),
#  ('▁we', 170),
#  ('▁were', 167),
#  ('▁all', 167),
#  ('▁him', 163),
#  ('▁me', 161),
#  ('▁no', 158),
#  ('▁her', 158),
#  ('▁by', 154),
#  ('▁been', 143),
#  ('s', 143),
#  (',"', 143),
#  ('."', 141),
#  ('▁so', 139),
#  ('▁one', 135),
#  ('▁when', 132),
#  ('▁are', 132),
#  ('▁an', 128),
#  ('▁or', 115),
#  ('▁up', 115),
#  ('▁would', 115),
#  ('▁who', 111),
#  ('ed', 108),
#  ('▁some', 106),
# ...

# %%
tokens
# Out:
# ['▁a',
#  '▁study',
#  '▁in',
#  '▁scarlet',
#  '▁arthur',
#  '▁con',
#  'an',
#  '▁do',
#  'yle',
#  '▁table',
#  '▁of',
#  '▁contents',
#  '▁part',
#  '▁i',
#  '▁mr.',
#  '▁sherlock',
#  '▁holmes',
#  '▁the',
#  '▁science',
#  '▁of',
#  '▁deduction',
#  '▁the',
#  '▁lauriston',
#  '▁garden',
#  '▁mystery',
#  '▁what',
#  '▁john',
#  '▁rance',
#  '▁had',
#  '▁to',
#  '▁tell',
#  '▁our',
#  '▁advertisement',
#  '▁brings',
#  '▁a',
#  '▁visitor',
#  '▁tobias',
#  '▁gregson',
#  '▁shows',
#  '▁what',
#  '▁he',
#  '▁can',
#  '▁do',
#  '▁light',
#  '▁in',
#  '▁the',
#  '▁darkness',
#  '▁part',
#  '▁ii',
#  '▁on',
#  '▁the',
#  '▁great',
#  '▁alkali',
#  '▁plain',
#  '▁the',
#  '▁flower',
#  '▁of',
#  '▁utah',
#  '▁john',
#  '▁ferrier',
#  '▁talks',
#  '▁with',
#  '▁the',
#  '▁prophet',
#  '▁a',
#  '▁flight',
#  '▁for',
#  '▁life',
#  '▁the',
#  '▁avenging',
#  '▁angels',
#  '▁a',
#  '▁continuation',
#  '▁of',
#  '▁the',
#  '▁reminiscences',
#  '▁of',
#  '▁john',
#  '▁watson,',
# ...

# %%
[t for t in freq if len(t[0]) > 1][:30]
# Out:
# [('▁the', 2493),
#  ('▁and', 1312),
#  ('▁of', 1209),
#  ('▁to', 1093),
#  ('▁a', 998),
#  ('▁i', 778),
#  ('▁he', 770),
#  ('▁in', 719),
#  ('▁his', 645),
#  ('▁was', 639),
#  ('▁that', 610),
#  ('▁had', 470),
#  ('▁it', 405),
#  ('▁you', 352),
#  ('▁with', 335),
#  ('▁as', 333),
#  ('▁at', 316),
#  ('▁which', 312),
#  ('▁for', 305),
#  ('▁my', 293),
#  ('▁have', 282),
#  ('▁is', 282),
#  ('▁be', 249),
#  ('▁on', 217),
#  ('▁there', 204),
#  ('▁upon', 197),
#  ('▁this', 194),
#  ('▁from', 183),
#  ('▁not', 180),
#  ('▁they', 173)]
