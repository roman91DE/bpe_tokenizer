# %%
from pathlib import Path
import main

# %%
txt = main.read_file(Path("./corpora/sherlock.txt"))

# %%
freq, tokens = main.bpe(txt, 1000, "w", normalize=True)
# Out:
# BPE Steps: 100%|██████████| 10/10 [00:42<00:00,  4.30s/100 steps]

# %%
freq
# Out:
# [('▁the', 2504),
#  (',', 1415),
#  ('▁and', 1321),
#  ('▁of', 1216),
#  ('▁to', 1155),
#  ('.', 1108),
#  ('▁a', 1070),
#  ('s', 872),
#  ('▁he', 856),
#  ('▁i', 855),
#  ('ed', 843),
#  ('▁in', 790),
#  ('▁was', 654),
#  ('▁his', 653),
#  ('▁that', 644),
#  ('ing', 609),
#  ('▁had', 476),
#  ('▁it', 450),
#  ('er', 410),
#  ('▁you', 408),
#  ('y', 404),
#  ('e', 387),
#  ('▁as', 379),
#  ('▁for', 358),
#  ('▁p', 339),
#  ('▁with', 337),
#  ('c', 333),
#  ('i', 327),
#  ('▁at', 320),
#  ('▁be', 319),
#  ('▁which', 315),
#  (',"', 300),
#  ('es', 298),
#  ('▁is', 297),
#  ('in', 295),
#  ('▁my', 295),
#  ('ar', 284),
#  ('g', 284),
#  ('▁have', 282),
#  ('▁f', 277),
#  ('it', 276),
#  ('t', 274),
#  ('▁c', 265),
#  ('."', 265),
#  ('en', 263),
#  ('o', 263),
#  ('n', 260),
#  ('a', 259),
#  ('▁m', 259),
#  ('u', 259),
#  ('ly', 258),
#  ('p', 254),
#  ('at', 253),
#  ('m', 252),
#  ('▁b', 251),
#  ('r', 250),
#  ('al', 247),
#  ('▁on', 241),
#  ('▁there', 240),
#  ('▁s', 238),
#  ('ent', 230),
#  ('b', 229),
#  ('▁l', 228),
#  ('on', 221),
#  ('ic', 217),
#  ('▁me', 213),
#  ('f', 212),
#  ('le', 211),
#  ('s,', 211),
#  ('▁we', 210),
#  ('▁t', 209),
#  ('an', 208),
#  ('l', 208),
#  ('▁st', 207),
#  ('▁this', 206),
#  ('▁r', 205),
#  ('ion', 202),
#  ('s.', 202),
#  ('▁all', 201),
#  ('or', 200),
#  ('▁not', 200),
#  ('▁upon', 197),
#  ('▁re', 191),
#  ('is', 184),
#  ('se', 184),
#  ('▁from', 183),
#  ('▁him', 180),
#  ('▁her', 180),
#  ('▁d', 179),
#  ('▁so', 178),
#  ('▁no', 177),
#  ('re', 176),
#  ('d', 174),
#  ('▁but', 174),
#  ('▁they', 173),
#  ('▁an', 172),
#  ("'s", 171),
#  ('v', 170),
#  ('▁w', 169),
#  ('▁were', 169),
#  ('e,', 164),
#  ('w', 160),
#  ('▁e', 159),
#  ('-', 159),
#  ('st', 157),
#  ('▁"', 155),
#  ('▁by', 154),
#  ('id', 154),
#  ('▁g', 149),
#  ('?"', 149),
#  ('h', 147),
#  ('ot', 147),
#  ('▁been', 147),
#  ('▁one', 147),
#  ('▁man', 142),
#  ('ow', 142),
#  ('▁out', 139),
#  ('ad', 139),
#  ('ve', 138),
#  ('▁up', 138),
#  ('▁when', 136),
#  ('▁h', 134),
#  ('▁are', 134),
#  ('ur', 132),
#  ('as', 128),
#  ('ce', 128),
#  ('k', 126),
#  ('▁who', 126),
#  ('▁"i', 126),
#  ('▁n', 125),
#  ('--', 125),
#  ('▁do', 122),
#  ('▁or', 122),
#  ('▁some', 121),
#  ('ir', 120),
#  ('▁su', 119),
#  ('▁ch', 119),
#  ('▁would', 119),
#  ('y,', 117),
#  ('▁them', 117),
#  ('ant', 116),
#  ('▁sh', 115),
#  ('▁said', 115),
#  ('ll', 115),
#  ('▁de', 114),
#  ('ut', 114),
#  ('ed,', 113),
#  ('um', 111),
#  ("'", 111),
#  ('▁what', 107),
#  ('om', 106),
#  ('ess', 106),
#  ('us', 105),
#  ('▁v', 104),
#  (';', 104),
#  ('ance', 103),
#  ('ri', 103),
#  ('▁over', 103),
#  ('ld', 103),
#  ('ist', 101),
#  ('il', 101),
#  ('es,', 101),
#  ('he', 99),
#  ('▁could', 99),
#  ('am', 99),
#  ('▁down', 99),
#  ('est', 99),
#  ('th', 98),
#  ('im', 98),
#  ('un', 98),
#  ('▁into', 98),
#  ('ter', 97),
#  ('▁ex', 97),
#  ('▁your', 97),
#  ('ation', 96),
#  ('et', 96),
#  ('▁tr', 96),
#  ('▁will', 96),
#  ('e.', 96),
#  ('ol', 95),
#  ('el', 94),
#  ('▁their', 94),
#  ('es.', 93),
#  ('nd', 91),
#  ('ag', 91),
#  ('▁she', 91),
#  ('ver', 90),
#  ('ain', 90),
#  ('▁if', 89),
#  ('ate', 87),
#  ('▁un', 87),
#  ('▁le', 87),
#  ('led', 87),
#  ('▁any', 87),
#  ('red', 87),
#  ('▁other', 86),
#  ('ac', 85),
#  ('ered', 84),
#  ('ro', 84),
#  ('▁more', 84),
#  ('▁', 82),
#  ('y.', 82),
#  ('ort', 82),
#  ('▁little', 82),
#  ('▁fe', 82),
#  ('▁ha', 82),
#  ('▁before', 81),
#  ('ch', 81),
#  ('▁has', 80),
#  ('ra', 79),
#  ('pt', 79),
#  ('ed.', 79),
#  ('▁th', 79),
#  ('▁then', 79),
#  ('and', 78),
#  ('▁pr', 78),
#  ('▁two', 78),
#  ('▁about', 77),
#  ('▁se', 77),
#  ('▁am', 76),
#  ('▁very', 75),
#  ('▁know', 75),
#  ('▁way', 75),
#  ('▁hand', 75),
#  ('one', 74),
#  ('x', 74),
#  ('▁now', 74),
#  ('▁al', 73),
#  ('ay', 73),
#  ('▁br', 72),
#  ('ers', 72),
#  ('ou', 72),
#  ('able', 71),
#  ('▁our', 71),
#  ('▁should', 71),
#  ('all', 71),
#  ('▁sc', 69),
#  ('ound', 69),
#  ('er,', 69),
#  ('ap', 69),
#  ('▁lo', 68),
#  ('▁pro', 68),
#  ('▁en', 68),
#  ('▁bo', 68),
#  ('ig', 68),
#  ('▁can', 67),
#  ('ge', 67),
#  ('ard', 67),
#  ('▁come', 67),
#  ('▁face', 67),
#  ('ure', 67),
#  ('▁holmes', 66),
#  ('▁came', 66),
#  ('▁ne', 66),
#  ('▁ar', 65),
#  ('em', 65),
#  ('ul', 65),
#  ('ie', 65),
#  ('▁li', 64),
#  ('▁us', 64),
#  ('ive', 63),
#  ('▁see', 63),
#  ('qu', 63),
#  ('▁long', 63),
#  ('▁"you', 62),
#  ('▁drebber', 62),
#  ('▁rem', 61),
#  ('ment', 61),
#  ('▁through', 61),
#  ('▁sa', 61),
#  ('▁than', 61),
#  ('ast', 61),
#  ('our', 60),
#  ('▁it.', 60),
#  ('▁well', 60),
#  ('▁cl', 60),
#  ('▁said,', 59),
#  ('?', 59),
#  ('▁gl', 59),
#  ('ved', 58),
#  ('▁sp', 58),
#  ('▁hope', 58),
#  ('▁day', 57),
#  ('▁time', 57),
#  ('▁young', 57),
#  ('!"', 57),
#  ('▁room', 57),
#  ('pe', 57),
#  ('▁con', 56),
#  ('▁ferrier', 56),
#  ('ous', 56),
#  ('▁did', 56),
#  ('ice', 56),
#  ('air', 56),
#  ('ven', 55),
#  ('▁go', 55),
#  ('▁found', 55),
#  ('▁after', 55),
#  ('▁how', 55),
#  ('▁own', 55),
#  ('ide', 55),
#  ('ly.', 55),
#  ('▁wat', 54),
#  ('ine', 54),
#  ('ence', 54),
#  ('▁him.', 54),
#  ('▁co', 54),
#  ('▁fl', 53),
#  ('▁j', 53),
#  ('os', 53),
#  ('▁saw', 53),
#  ('▁"the', 53),
#  ('ing,', 53),
#  ('▁po', 53),
#  ('▁every', 53),
#  ('▁these', 53),
#  ('▁sherlock', 52),
#  ('if', 52),
#  ('▁pl', 52),
#  ('ight', 51),
#  ('z', 51),
#  ('ff', 51),
#  ('ally', 51),
#  ('ust', 51),
#  ('ud', 51),
#  ('▁himself', 51),
#  ('ion.', 51),
#  ('▁sm', 51),
#  ('▁last', 50),
#  ('▁back', 50),
#  ('▁door', 50),
#  ('▁wr', 50),
#  ('ity', 49),
#  ('ep', 49),
#  ('▁off', 49),
#  ('▁str', 49),
#  ('own', 49),
#  ('oo', 49),
#  ('▁gr', 49),
#  ('▁however,', 48),
#  ('▁here', 48),
#  ('ill', 48),
#  ('▁such', 48),
#  ('king', 48),
#  ('ick', 48),
#  ('ang', 48),
#  ('▁great', 47),
#  ('▁must', 47),
#  ('ving', 47),
#  ('ish', 46),
#  ('ated', 46),
#  ('▁acc', 46),
#  ('▁per', 46),
#  ('▁too', 46),
#  ('are', 46),
#  ('lo', 46),
#  ('▁may', 46),
#  ('▁thought', 46),
#  ('▁until', 46),
#  ('▁stangerson', 46),
#  ('ull', 45),
#  ('ong', 45),
#  ('ip', 45),
#  ('▁qu', 45),
#  ('▁made', 45),
#  ('er.', 45),
#  ('▁"it', 45),
#  ('pp', 45),
#  ('▁part', 44),
#  ('▁gregson', 44),
#  ('ber', 44),
#  ('▁ho', 44),
#  ('▁companion', 44),
#  ('▁much', 44),
#  ('▁away', 44),
#  ('ite', 44),
#  ('ck', 44),
#  ('ked', 44),
#  ('anc', 43),
#  ('▁imp', 43),
#  ('▁com', 43),
#  ('ious', 43),
#  ('▁asked', 43),
#  ('▁might', 43),
#  ('▁cle', 43),
#  ('▁house', 43),
#  ('▁cab', 43),
#  ('▁dis', 42),
#  ('ly,', 42),
#  ('ak', 42),
#  ('▁never', 42),
#  ('ves', 42),
#  ('▁bl', 42),
#  ('ind', 42),
#  ('ing.', 42),
#  ('ical', 41),
#  ('▁it,', 41),
#  ('▁pass', 41),
#  ('▁many', 41),
#  ('▁under', 41),
#  ('▁o', 41),
#  ('▁night', 41),
#  ('ct', 41),
#  ('▁ab', 41),
#  ('ature', 41),
#  ('pect', 41),
#  ('▁fa', 41),
#  ('▁heart', 41),
#  ("▁'", 41),
#  ('▁ke', 41),
#  ('ary', 41),
#  ('▁"\'', 41),
#  ('▁john', 40),
#  ('▁des', 40),
#  ('ord', 40),
#  ('▁mind', 40),
#  ('▁cr', 40),
#  ('de', 40),
#  ('▁like', 40),
#  ('▁shall', 40),
#  ('hed', 40),
#  ('▁ey', 40),
#  ('▁mr.', 39),
#  ('art', 39),
#  ('av', 39),
#  ('age', 39),
#  ('▁turn', 39),
#  ('▁appeared', 39),
#  ('ened', 39),
#  ('ab', 39),
#  ('act', 39),
#  ('▁nothing', 38),
#  ('▁pre', 38),
#  ('ss', 38),
#  ('▁old', 38),
#  ('▁int', 38),
#  ('▁though', 38),
#  ('ue', 38),
#  ('ore', 38),
#  ('ful', 38),
#  ('▁sl', 38),
#  ('▁once', 37),
#  ('▁wor', 37),
#  ("'ll", 37),
#  ('▁him,', 37),
#  ('ark', 37),
#  ('▁jefferson', 37),
#  ('▁show', 36),
#  ('ire', 36),
#  ('▁even', 36),
#  ('▁street', 36),
#  ('ars', 36),
#  ('▁seem', 36),
#  ('▁only', 36),
#  ('nt', 36),
#  ('▁put', 36),
#  ('ach', 36),
#  ('▁where', 35),
#  ('ome', 35),
#  ("▁don't", 35),
#  ('▁app', 35),
#  ('▁just', 35),
#  ('▁eyes', 35),
#  ('▁case', 35),
#  ('▁good', 35),
#  ('▁"we', 35),
#  ('▁head', 35),
#  ('ched', 34),
#  ('▁enough', 34),
#  ('iz', 34),
#  ('man', 34),
#  ('▁matter', 34),
#  ('▁men', 34),
#  ('▁point', 34),
#  ('ier', 34),
#  ('▁road', 34),
#  ('ount', 33),
#  ('▁new', 33),
#  ('less', 33),
#  ('ible', 33),
#  ('▁say', 33),
#  ('▁said.', 33),
#  ('ect', 33),
#  ('▁them.', 33),
#  ('▁find', 33),
#  ('▁again', 33),
#  ('▁whole', 33),
#  ('rave', 33),
#  ('▁hor', 33),
#  ('lt', 33),
#  ('ings', 32),
#  ('▁ye', 32),
#  ('▁em', 32),
#  ('ile', 32),
#  ('▁get', 32),
#  ('▁answered', 32),
#  ('▁res', 32),
#  ('itt', 32),
#  ('▁word', 32),
#  ('ained', 32),
#  ('▁done', 32),
#  ('▁wh', 32),
#  ('ared', 32),
#  ('▁still', 32),
#  ('▁tell', 31),
#  ('▁comp', 31),
#  ('▁ass', 31),
#  ('▁ent', 31),
#  ('▁inc', 31),
#  ('aking', 31),
#  ('▁round', 31),
#  ('▁holm', 31),
#  ('▁set', 31),
#  ('▁while', 31),
#  ('▁te', 31),
#  ('ried', 31),
#  ('▁ad', 30),
#  ('ies', 30),
#  ('ail', 30),
#  ('▁bec', 30),
#  ('▁spe', 30),
#  ('ion,', 30),
#  ('ath', 30),
#  ('▁remarked', 30),
#  ('au', 30),
#  ('▁against', 30),
#  ('ress', 30),
#  ('ood', 30),
#  ('▁right', 30),
#  ('▁small', 30),
#  ('▁its', 30),
#  ('▁end', 30),
#  ('ling', 30),
#  ('▁most', 30),
#  ('▁blood', 30),
#  ('▁hun', 30),
#  ('▁those', 30),
#  ('▁ins', 30),
#  ('▁bre', 30),
#  ('▁y', 30),
#  ('▁dre', 29),
#  ('▁"and', 29),
#  ('▁che', 29),
#  ('▁yet', 29),
#  ('ass', 29),
#  ('▁im', 29),
#  ('▁death', 29),
#  ('arr', 29),
#  ('▁op', 29),
#  ('▁gu', 29),
#  ('▁name', 29),
#  ('ison', 29),
#  ('▁let', 29),
#  ('▁left', 29),
#  ('▁knew', 29),
#  ('▁girl', 29),
#  ('▁sil', 29),
#  ('▁mountain', 29),
#  ('▁father', 29),
#  ('let', 28),
#  ('ement', 28),
#  ('ness', 28),
#  ('▁att', 28),
#  ('▁tim', 28),
#  ('hing', 28),
#  ('att', 28),
#  ('az', 28),
#  ('▁det', 28),
#  ('ither', 28),
#  ('▁dr', 28),
#  ('▁me.', 28),
#  ('▁ob', 28),
#  ('▁spoke', 28),
#  ('!', 28),
#  ('▁man,', 28),
#  ('xt', 28),
#  ('▁fr', 28),
#  ('ert', 28),
#  ('gg', 28),
#  ('ished', 28),
#  ('▁wind', 28),
#  ('ently', 28),
#  ('▁without', 28),
#  ('▁light', 27),
#  ('▁having', 27),
#  ('▁nor', 27),
#  ('▁bri', 27),
#  ('ack', 27),
#  ('ere', 27),
#  ('▁far', 27),
#  ('ave', 27),
#  ('▁exp', 27),
#  ('orn', 27),
#  ('ation.', 27),
#  ('▁answered.', 27),
#  ('▁"b', 27),
#  ('▁work', 27),
#  ('▁looking', 27),
#  ('▁think', 27),
#  ('ions', 27),
#  ('▁quest', 27),
#  ('▁lay', 27),
#  ('▁wom', 27),
#  ('agg', 27),
#  ('▁heard', 27),
#  ('▁lestrade', 27),
#  ('ied', 27),
#  ('ph', 27),
#  ('▁dark', 26),
#  ('▁pres', 26),
#  ('land', 26),
#  ('sh', 26),
#  ('ired', 26),
#  ('ined', 26),
#  ('▁friend', 26),
#  ('▁gave', 26),
#  ('▁comm', 26),
#  ('▁"that', 26),
#  ('▁fellow', 26),
#  ('▁being', 26),
#  ("n't", 26),
#  ('▁bel', 26),
#  ('▁few', 26),
#  ('▁dro', 26),
#  ('ow,', 26),
#  ('▁fo', 26),
#  ('▁kn', 26),
#  ('▁ro', 26),
#  ('▁seen', 26),
#  ('▁vo', 26),
#  ('▁ever', 26),
#  ('▁lucy', 26),
#  ('ower', 25),
#  ('▁took', 25),
#  ('▁sur', 25),
#  ('ached', 25),
#  ('▁ind', 25),
#  ('▁ser', 25),
#  ('▁fre', 25),
#  ('▁soon', 25),
#  ('▁together', 25),
#  ('▁first', 25),
#  ('▁morning', 25),
#  ('▁return', 25),
#  ('▁form', 25),
#  ('▁"h', 25),
#  ('ject', 25),
#  ('▁dist', 25),
#  ('▁"n', 25),
#  ('▁inf', 25),
#  ('▁crim', 25),
#  ('▁"there', 25),
#  ('▁di', 25),
#  ('▁conf', 25),
#  ('▁car', 25),
#  ('▁gre', 25),
#  ('▁myster', 24),
#  ('▁arm', 24),
#  ('▁cour', 24),
#  ('gh', 24),
#  ('▁adv', 24),
#  ('▁same', 24),
#  ('▁myself', 24),
#  ('▁hands', 24),
#  ('▁mean', 24),
#  ('pped', 24),
#  ('▁"what', 24),
#  ('▁dra', 24),
#  ('ise', 24),
#  ('▁"he', 24),
#  ('rang', 24),
#  ('▁add', 24),
#  ('-b', 24),
#  ('▁wall', 24),
#  ('▁child', 24),
#  ('▁ag', 24),
#  ('▁call', 24),
#  ('▁three', 24),
#  ('pl', 24),
#  ('▁followed', 24),
#  ('ily', 24),
#  ('ict', 24),
#  ('ke', 24),
#  ('▁obser', 24),
#  ('arly', 24),
#  ('▁mar', 24),
#  ('▁tw', 24),
#  ("▁o'", 24),
#  ('ait', 24),
#  ('▁daughter', 24),
#  ('▁cont', 23),
#  ('▁continu', 23),
#  ('▁jo', 23),
#  ('cl', 23),
#  ('se,', 23),
#  ('ized', 23),
#  ('▁wild', 23),
#  ('▁reason', 23),
#  ('▁dri', 23),
#  ('▁feet', 23),
#  ('j', 23),
#  ('▁another', 23),
#  ('wh', 23),
#  ('▁among', 23),
#  ('▁went', 23),
#  ('arp', 23),
#  ('▁within', 23),
#  ('orm', 23),
#  ('▁pol', 23),
#  ("▁man's", 23),
#  ('▁got', 23),
#  ('ove', 23),
#  ('ook', 23),
#  ('▁sin', 23),
#  ('▁evid', 23),
#  ('▁stood', 23),
#  ('▁aff', 23),
#  ('▁ut', 22),
#  ('▁prop', 22),
#  ('int', 22),
#  ('1', 22),
#  ('▁learn', 22),
#  ('▁mur', 22),
#  ('▁poss', 22),
#  ('▁mon', 22),
#  ('▁k', 22),
#  ('▁take', 22),
#  ('▁reco', 22),
#  ('ised', 22),
#  ('▁hardly', 22),
#  ('ying', 22),
#  ('ble', 22),
#  ('▁asked.', 22),
#  ('▁gentle', 22),
#  ('ing-', 22),
#  ('▁stre', 22),
#  ('▁inst', 22),
#  ('▁hour', 22),
#  ('ty', 22),
#  ('▁"m', 22),
#  ('▁better', 22),
#  ('▁between', 22),
#  ('▁use', 22),
#  ('ake', 22),
#  ('ci', 22),
#  ('▁four', 22),
#  ('▁moment', 22),
#  ('▁along', 22),
#  ('wn', 22),
#  ('▁cried', 22),
#  (",'", 22),
#  ('other', 22),
#  ('▁mormon', 22),
#  ('▁stud', 21),
#  ('▁plain', 21),
#  ('▁life', 21),
#  ('uck', 21),
#  ('▁thre', 21),
#  ('sp', 21),
#  ('▁met', 21),
#  ('atter', 21),
#  ('▁"wh', 21),
#  ('▁strang', 21),
#  ('ory', 21),
#  ('▁supp', 21),
#  ('s."', 21),
#  ('▁both', 21),
#  ('▁me,', 21),
#  ('▁lau', 21),
#  ('▁gi', 21),
#  ('▁white', 21),
#  ('od', 21),
#  ('▁walked', 21),
#  ('▁lif', 21),
#  ('uring', 21),
#  ('▁inter', 21),
#  ('▁something', 21),
#  ('way', 21),
#  ('ceed', 20),
#  ('ps', 20),
#  ('▁mis', 20),
#  ('▁across', 20),
#  ('erm', 20),
#  ('▁next', 20),
#  ('ght', 20),
#  ('▁make', 20),
#  ('▁stand', 20),
#  ('▁start', 20),
#  ('self', 20),
#  ('▁cried,', 20),
#  ('▁want', 20),
#  ('▁rather', 20),
#  ('▁care', 20),
#  ('end', 20),
#  ('ek', 20),
#  ('▁read', 20),
#  ('▁led', 20),
#  ('▁doubt', 20),
#  ('▁appear', 20),
#  ('co', 20),
#  (".'", 20),
#  ('▁vi', 20),
#  ('▁"w', 20),
#  ('op', 20),
#  ('▁help', 20),
#  ('-f', 20),
#  ('▁lestrad', 20),
#  ('▁look', 20),
#  ('▁sat', 20),
#  ('▁detective', 20),
#  ('▁secret', 20),
#  ('▁rock', 20),
#  ('ience', 19),
#  ('uct', 19),
#  ('▁la', 19),
#  ('▁rep', 19),
#  ('▁chap', 19),
#  ('▁second', 19),
#  ('▁brought', 19),
#  ('▁ord', 19),
#  ('h,', 19),
#  ('ame', 19),
#  ('ably', 19),
#  ('riv', 19),
#  ('▁hot', 19),
#  ('▁began', 19),
#  ('▁sight', 19),
#  ('▁thing', 19),
#  ('iled', 19),
#  ('▁del', 19),
#  ('▁u', 19),
#  ('▁sk', 19),
#  ('▁whe', 19),
#  ('▁looked', 19),
#  ('▁anything', 19),
#  ('hes', 19),
#  ('out', 19),
#  ('▁sim', 19),
#  ('"', 19),
#  ('▁result', 19),
#  ('igh', 19),
#  ('ways', 19),
#  ('▁ext', 19),
#  ('▁tre', 19),
#  ('ple', 19),
#  ('-l', 19),
#  ('▁give', 19),
#  ('▁fact', 19),
#  ('▁clo', 19),
#  ('▁half', 19),
#  ('▁sir', 19),
#  ('▁terrible', 19),
#  ('▁ring', 19),
#  ('▁garden', 18),
#  ('▁concl', 18),
#  ('▁doct', 18),
#  ('▁already', 18),
#  ('▁able', 18),
#  ('▁wal', 18),
#  ('ont', 18),
#  ('▁ru', 18),
#  ('les', 18),
#  ('▁consider', 18),
#  ('▁min', 18),
#  ('▁sol', 18),
#  ('▁idea', 18),
#  ('▁"d', 18),
#  ('▁eas', 18),
#  ('▁el', 18),
#  ('oured', 18),
#  ('▁broad', 18),
#  ('▁step', 18),
#  ('▁disco', 18),
#  ('▁gold', 18),
#  ('▁sign', 18),
#  ('▁difficult', 18),
#  ('ry', 18),
#  ('dden', 18),
#  ('▁people', 18),
#  ('▁"th', 18),
#  ("'t", 18),
#  ('vid', 18),
#  ('▁gone', 18),
#  ('ost', 18),
#  ('oud', 18),
#  ('aged', 18),
#  ('▁cre', 18),
#  ('ped', 18),
#  ('atch', 18),
#  ('▁hur', 18),
#  ('aced', 18),
#  ('▁horse', 18),
#  ('▁farm', 18),
#  ('▁dep', 17),
#  ('▁land', 17),
#  ('▁whom', 17),
#  ('▁murder', 17),
#  ('-h', 17),
#  ('▁hard', 17),
#  ('▁cur', 17),
#  ('gn', 17),
#  ('▁expression', 17),
#  ('▁"a', 17),
#  ('▁"no', 17),
#  ('▁taken', 17),
#  ('▁going', 17),
#  ('▁sure', 17),
#  ('▁place', 17),
#  ('▁occas', 17),
#  ('▁"y', 17),
#  ('▁certain', 17),
#  ('wards', 17),
#  ('pping', 17),
#  ('ever', 17),
#  ('▁act', 17),
#  ('▁why', 17),
#  ('ink', 17),
#  ('nder', 17),
#  ('▁occ', 17),
#  ('ould', 17),
#  (':', 17),
#  ('ward', 17),
#  ('ose', 16),
#  ('ult', 16),
#  ('her', 16),
#  ('arn', 16),
#  ('▁ret', 15),
#  ('▁pe', 15),
#  ('urn', 15),
#  ('ady', 15),
#  ('▁answ', 15),
#  ('we', 15),
#  ('▁af', 14),
#  ('ith', 14),
#  ('▁"t', 14),
#  ('ther', 14),
#  ('▁express', 14),
#  ('▁cas', 14),
#  ('▁beg', 14),
#  ('▁cons', 14),
#  ('▁detect', 14),
#  ('▁follow', 13),
#  ('ign', 13),
#  ('very', 13),
#  ('▁ac', 13),
#  ('2', 13),
#  ('ather', 13),
#  ('▁thr', 13),
#  ('ace', 13),
#  ('▁murd', 13),
#  ('son', 12),
#  ('cc', 12),
#  ('ich', 12),
#  ('aken', 12),
#  ('3', 12),
#  ("on't", 12),
#  ('ade', 11),
#  ('ng', 11),
#  ('uc', 11),
#  ('aught', 11),
#  ('▁cri', 11),
#  ('lock', 11),
#  ('▁bro', 10),
#  ('ret', 10),
#  ('fore', 10),
#  ('▁appe', 10),
#  ('r.', 10),
#  ('me', 10),
#  ('thing', 10),
#  ('▁ap', 10),
#  ('▁somet', 10),
#  ('erson', 10),
#  ('▁diff', 10),
#  ('▁compan', 9),
#  ('ertain', 9),
#  ('get', 8),
#  ('▁morn', 8),
#  ('4', 8),
#  ('▁kne', 8),
#  ('▁har', 8),
#  ('▁fri', 8),
#  ('dd', 7),
#  ('ough', 7),
#  ('▁daught', 7),
#  ('ouse', 7),
#  ('▁terri', 7),
#  ('8', 6),
#  ('ft', 6),
#  ('oke', 6),
#  ('6', 6),
#  ('llow', 6),
#  ('▁however', 6),
#  ('ã', 6),
#  ('▁contin', 6),
#  ('▁sec', 6),
#  ('▁ferri', 6),
#  ('▁bot', 5),
#  ('▁mu', 5),
#  ('arked', 5),
#  ('lf', 5),
#  ...]

# %%
tokens
# Out:
# ['▁a',
#  '▁stud',
#  'y',
#  '▁in',
#  '▁sc',
#  'ar',
#  'let',
#  '▁ar',
#  'th',
#  'ur',
#  '▁con',
#  'an',
#  '▁do',
#  'y',
#  'le',
#  '▁t',
#  'able',
#  '▁of',
#  '▁cont',
#  'ent',
#  's',
#  '▁part',
#  '▁i',
#  '▁mr.',
#  '▁sherlock',
#  '▁holmes',
#  '▁the',
#  '▁sc',
#  'ience',
#  '▁of',
#  '▁d',
#  'ed',
#  'uct',
#  'ion',
#  '▁the',
#  '▁la',
#  'ur',
#  'ist',
#  'on',
#  '▁garden',
#  '▁myster',
#  'y',
#  '▁what',
#  '▁john',
#  '▁r',
#  'ance',
#  '▁had',
#  '▁to',
#  '▁tell',
#  '▁our',
#  '▁ad',
#  'ver',
#  't',
#  'is',
#  'ement',
#  '▁br',
#  'ings',
#  '▁a',
#  '▁v',
#  'is',
#  'it',
#  'or',
#  '▁to',
#  'b',
#  'i',
#  'as',
#  '▁gregson',
#  '▁show',
#  's',
#  '▁what',
#  '▁he',
#  '▁can',
#  '▁do',
#  '▁light',
#  '▁in',
#  '▁the',
#  '▁dark',
#  'ness',
#  '▁part',
#  '▁i',
#  'i',
#  '▁on',
#  '▁the',
#  '▁great',
#  '▁al',
#  'k',
#  'al',
#  'i',
#  '▁plain',
#  '▁the',
#  '▁fl',
#  'ower',
#  '▁of',
#  '▁ut',
#  'a',
#  'h',
#  '▁john',
#  '▁ferrier',
#  '▁t',
#  'al',
#  'k',
#  's',
#  '▁with',
#  '▁the',
#  '▁prop',
#  'he',
#  't',
#  '▁a',
#  '▁fl',
#  'ight',
#  '▁for',
#  '▁life',
#  '▁the',
#  '▁a',
#  'ven',
#  'g',
#  'ing',
#  '▁an',
#  'g',
#  'el',
#  's',
#  '▁a',
#  '▁continu',
#  'ation',
#  '▁of',
#  '▁the',
#  '▁rem',
#  'in',
#  'is',
#  'c',
#  'en',
#  'c',
#  'es',
#  '▁of',
#  '▁john',
#  '▁wat',
#  'son',
#  ',',
#  '▁m',
#  '.',
#  'd',
#  '.',
#  '▁the',
#  '▁concl',
#  'us',
#  'ion',
#  '▁part',
#  '▁i',
#  '▁',
#  '(',
#  'b',
#  'e',
#  'ing',
#  '▁a',
#  '▁rep',
#  'r',
#  'int',
#  '▁from',
#  '▁the',
#  '▁rem',
#  'in',
#  'is',
#  'c',
#  'en',
#  'c',
#  'es',
#  '▁of',
#  '▁john',
#  '▁h',
#  '.',
#  '▁wat',
#  'son',
#  ',',
#  '▁m',
#  '.',
#  'd',
#  '.',
#  ',',
#  '▁l',
#  'ate',
#  '▁of',
#  '▁the',
#  '▁arm',
#  'y',
#  '▁m',
#  'ed',
#  'ical',
#  '▁dep',
#  'art',
#  'ment',
#  '.',
#  ')',
#  '▁chap',
#  'ter',
#  '▁i',
#  '▁mr.',
#  '▁sherlock',
#  '▁holmes',
#  '▁in',
#  '▁the',
#  '▁ye',
#  'ar',
#  '▁',
#  '1',
#  '8',
#  '7',
#  '8',
#  '▁i',
#  '▁took',
#  '▁my',
#  '▁de',
#  'g',
#  're',
#  'e',
#  '▁of',
#  '▁doct',
#  'or',
#  '▁of',
#  '▁m',
#  'ed',
#  'ic',
#  'ine',
#  '▁of',
#  '▁the',
#  '▁un',
#  'i',
#  'ver',
#  's',
#  'ity',
#  '▁of',
#  '▁lo',
#  'nd',
#  'on',
#  ',',
#  '▁and',
#  '▁pro',
#  'ceed',
#  'ed',
#  '▁to',
#  '▁n',
#  'et',
#  'le',
#  'y',
#  '▁to',
#  '▁go',
#  '▁through',
#  '▁the',
#  '▁cour',
#  'se',
#  '▁pres',
#  'c',
#  'ri',
#  'b',
#  'ed',
#  '▁for',
#  '▁sur',
#  'ge',
#  'on',
#  's',
#  '▁in',
#  '▁the',
#  '▁arm',
#  'y.',
#  '▁having',
#  '▁comp',
#  'let',
#  'ed',
#  '▁my',
#  '▁stud',
#  'ies',
#  '▁there',
#  ',',
#  '▁i',
#  '▁was',
#  '▁d',
#  'u',
#  'ly',
#  '▁att',
#  'ached',
#  '▁to',
#  '▁the',
#  '▁f',
#  'if',
#  'th',
#  '▁nor',
#  'th',
#  'um',
#  'ber',
#  'land',
#  '▁f',
#  'us',
#  'il',
#  'i',
#  'ers',
#  '▁as',
#  '▁ass',
#  'ist',
#  'ant',
#  '▁sur',
#  'ge',
#  'on',
#  '.',
#  '▁the',
#  '▁re',
#  'g',
#  'im',
#  'ent',
#  '▁was',
#  '▁st',
#  'ation',
#  'ed',
#  '▁in',
#  '▁ind',
#  'i',
#  'a',
#  '▁at',
#  '▁the',
#  '▁tim',
#  'e,',
#  '▁and',
#  '▁before',
#  '▁i',
#  '▁could',
#  '▁jo',
#  'in',
#  '▁it,',
#  '▁the',
#  '▁second',
#  '▁af',
#  'gh',
#  'an',
#  '▁w',
#  'ar',
#  '▁had',
#  '▁bro',
#  'k',
#  'en',
#  '▁out',
#  '.',
#  '▁on',
#  '▁land',
#  'ing',
#  '▁at',
#  '▁b',
#  'om',
#  'b',
#  'ay',
#  ',',
#  '▁i',
#  '▁learn',
#  'ed',
#  '▁that',
#  '▁my',
#  '▁c',
#  'or',
#  'ps',
#  '▁had',
#  '▁adv',
#  'anc',
#  'ed',
#  '▁through',
#  '▁the',
#  '▁pass',
#  'es,',
#  '▁and',
#  '▁was',
#  '▁already',
#  '▁de',
#  'ep',
#  '▁in',
#  '▁the',
#  '▁en',
#  'em',
#  'y',
#  "'s",
#  '▁c',
#  'ount',
#  'r',
#  'y.',
#  '▁i',
#  '▁follow',
#  'ed,',
#  '▁however,',
#  '▁with',
#  '▁many',
#  '▁other',
#  '▁off',
#  'ic',
#  'ers',
#  '▁who',
#  '▁were',
#  '▁in',
#  '▁the',
#  '▁same',
#  '▁s',
#  'it',
#  'u',
#  'ation',
#  '▁as',
#  '▁myself',
#  ',',
#  '▁and',
#  '▁su',
#  'c',
#  'ceed',
#  'ed',
#  '▁in',
#  '▁re',
#  'ac',
#  'hing',
#  '▁c',
#  'and',
#  'a',
#  'h',
#  'ar',
#  '▁in',
#  '▁sa',
#  'f',
#  'et',
#  'y,',
#  '▁where',
#  '▁i',
#  '▁found',
#  '▁my',
#  '▁re',
#  'g',
#  'im',
#  'ent',
#  ',',
#  '▁and',
#  '▁at',
#  '▁once',
#  '▁ent',
#  'ered',
#  '▁upon',
#  '▁my',
#  '▁new',
#  '▁d',
#  'ut',
#  'i',
#  'es.',
#  '▁the',
#  '▁c',
#  'am',
#  'p',
#  'a',
#  'ign',
#  '▁brought',
#  '▁h',
#  'on',
#  'our',
#  's',
#  '▁and',
#  '▁pr',
#  'om',
#  'ot',
#  'ion',
#  '▁to',
#  '▁man',
#  'y,',
#  '▁but',
#  '▁for',
#  '▁me',
#  '▁it',
#  '▁had',
#  '▁nothing',
#  '▁but',
#  '▁mis',
#  'f',
#  'ort',
#  'un',
#  'e',
#  '▁and',
#  '▁dis',
#  'as',
#  'ter',
#  '.',
#  '▁i',
#  '▁was',
#  '▁rem',
#  'o',
#  'ved',
#  '▁from',
#  '▁my',
#  '▁bri',
#  'g',
#  'ade',
#  '▁and',
#  '▁att',
#  'ached',
#  '▁to',
#  '▁the',
#  '▁b',
#  'er',
#  'k',
#  'sh',
#  'ire',
#  's,',
#  '▁with',
#  '▁whom',
#  '▁i',
#  '▁ser',
#  'ved',
#  '▁at',
#  '▁the',
#  '▁f',
#  'at',
#  'al',
#  '▁b',
#  'att',
#  'le',
#  '▁of',
#  '▁m',
#  'a',
#  'i',
#  'w',
#  'and',
#  '.',
#  '▁there',
#  '▁i',
#  '▁was',
#  '▁str',
#  'uck',
#  '▁on',
#  '▁the',
#  '▁should',
#  'er',
#  '▁by',
#  '▁a',
#  '▁je',
#  'z',
#  'ail',
#  '▁b',
#  'ull',
#  'et',
#  ',',
#  '▁which',
#  '▁sh',
#  'att',
#  'ered',
#  '▁the',
#  '▁b',
#  'one',
#  '▁and',
#  '▁g',
#  'ra',
#  'z',
#  'ed',
#  '▁the',
#  '▁su',
#  'b',
#  'cl',
#  'av',
#  'i',
#  'an',
#  '▁ar',
#  'ter',
#  'y.',
#  '▁i',
#  '▁should',
#  '▁have',
#  '▁f',
#  'all',
#  'en',
#  '▁into',
#  '▁the',
#  '▁hands',
#  '▁of',
#  '▁the',
#  '▁murder',
#  'ous',
#  '▁g',
#  'h',
#  'az',
#  'is',
#  '▁had',
#  '▁it',
#  '▁not',
#  '▁been',
#  '▁for',
#  '▁the',
#  '▁de',
#  'v',
#  'ot',
#  'ion',
#  '▁and',
#  '▁cour',
#  'age',
#  '▁sh',
#  'own',
#  '▁by',
#  '▁mur',
#  'r',
#  'ay',
#  ',',
#  '▁my',
#  '▁ord',
#  'er',
#  'ly,',
#  '▁who',
#  '▁thre',
#  'w',
#  '▁me',
#  '▁across',
#  '▁a',
#  '▁p',
#  'ack',
#  '-h',
#  'or',
#  'se,',
#  '▁and',
#  '▁su',
#  'c',
#  'ceed',
#  'ed',
#  '▁in',
#  '▁br',
#  'ing',
#  'ing',
#  '▁me',
#  '▁sa',
#  'f',
#  'e',
#  'ly',
#  '▁to',
#  '▁the',
#  '▁br',
#  'it',
#  'ish',
#  '▁l',
#  'in',
#  'es.',
#  '▁wor',
#  'n',
#  '▁with',
#  '▁p',
#  'ain',
#  ',',
#  '▁and',
#  '▁we',
#  'ak',
#  '▁from',
#  '▁the',
#  '▁pro',
#  'l',
#  'ong',
#  'ed',
#  '▁hard',
#  'sh',
#  'ip',
#  's',
#  '▁which',
#  '▁i',
#  '▁had',
#  '▁under',
#  'g',
#  'on',
#  'e,',
#  '▁i',
#  '▁was',
#  '▁rem',
#  'o',
#  'v',
#  'ed,',
#  '▁with',
#  '▁a',
#  '▁great',
#  '▁tr',
#  'ain',
#  '▁of',
#  '▁w',
#  'ound',
#  'ed',
#  '▁su',
#  'ff',
#  'ere',
#  'r',
#  's,',
#  '▁to',
#  '▁the',
#  '▁b',
#  'as',
#  'e',
#  '▁ho',
#  'sp',
#  'it',
#  'al',
#  '▁at',
#  '▁p',
#  'es',
#  'h',
#  'a',
#  'w',
#  'ar',
#  '.',
#  '▁here',
#  '▁i',
#  '▁r',
#  'all',
#  'i',
#  'ed,',
#  '▁and',
#  '▁had',
#  '▁already',
#  '▁imp',
#  'ro',
#  'ved',
#  '▁so',
#  '▁far',
#  '▁as',
#  '▁to',
#  '▁be',
#  '▁able',
#  '▁to',
#  '▁wal',
#  'k',
#  '▁about',
#  '▁the',
#  '▁w',
#  'ard',
#  's,',
#  '▁and',
#  '▁even',
#  '▁to',
#  '▁b',
#  'as',
#  'k',
#  '▁a',
#  '▁little',
#  '▁upon',
#  '▁the',
#  '▁',
#  'ver',
#  'and',
#  'a',
#  'h,',
#  '▁when',
#  '▁i',
#  '▁was',
#  '▁str',
#  'uck',
#  '▁down',
#  '▁by',
#  '▁ent',
#  'er',
#  'ic',
#  '▁fe',
#  'ver',
#  ',',
#  '▁that',
#  '▁cur',
#  'se',
#  '▁of',
#  '▁our',
#  '▁ind',
#  'i',
#  'an',
#  '▁poss',
#  'ess',
#  'ion',
#  's.',
#  '▁for',
#  '▁mon',
#  'th',
#  's',
#  '▁my',
#  '▁life',
#  '▁was',
#  '▁des',
#  'p',
#  'a',
#  'ired',
#  '▁of',
#  ',',
#  '▁and',
#  '▁when',
#  '▁at',
#  '▁last',
#  '▁i',
#  '▁came',
#  '▁to',
#  '▁myself',
#  '▁and',
#  '▁bec',
#  'ame',
#  '▁con',
#  'v',
#  'al',
#  'es',
#  'c',
#  'ent',
#  ',',
#  '▁i',
#  '▁was',
#  '▁so',
#  '▁we',
#  'ak',
#  '▁and',
#  '▁em',
#  'ac',
#  'i',
#  'ated',
#  '▁that',
#  '▁a',
#  '▁m',
#  'ed',
#  'ical',
#  '▁bo',
#  'ard',
#  '▁det',
#  'erm',
#  'ined',
#  '▁that',
#  '▁not',
#  '▁a',
#  '▁day',
#  '▁should',
#  '▁be',
#  '▁lo',
#  'st',
#  '▁in',
#  '▁se',
#  'nd',
#  'ing',
#  '▁me',
#  '▁back',
#  '▁to',
#  '▁en',
#  'g',
#  'land',
#  '.',
#  '▁i',
#  '▁was',
#  '▁dis',
#  'p',
#  'at',
#  'ched',
#  ',',
#  '▁acc',
#  'ord',
#  'ing',
#  'ly,',
#  '▁in',
#  '▁the',
#  '▁tr',
#  'oo',
#  'p',
#  'sh',
#  'ip',
#  '▁or',
#  'ont',
#  'es,',
#  '▁and',
#  '▁land',
#  'ed',
#  '▁a',
#  '▁mon',
#  'th',
#  '▁l',
#  'at',
#  'er',
#  '▁on',
#  '▁p',
#  'ort',
#  's',
#  'm',
#  'ou',
#  'th',
#  '▁j',
#  'et',
#  't',
#  'y,',
#  '▁with',
#  '▁my',
#  '▁he',
#  'al',
#  'th',
#  '▁i',
#  'r',
#  'ret',
#  'ri',
#  'e',
#  'v',
#  'ably',
#  '▁ru',
#  'in',
#  'ed,',
#  '▁but',
#  '▁with',
#  '▁per',
#  'm',
#  'is',
#  's',
#  'ion',
#  '▁from',
#  '▁a',
#  '▁p',
#  'at',
#  'er',
#  'n',
#  'al',
#  '▁go',
#  'ver',
#  'n',
#  'ment',
#  '▁to',
#  '▁spe',
#  'nd',
#  '▁the',
#  '▁next',
#  '▁n',
#  'ine',
#  '▁mon',
#  'th',
#  's',
#  '▁in',
#  '▁att',
#  'em',
#  'pt',
#  'ing',
#  '▁to',
#  '▁imp',
#  'ro',
#  've',
#  '▁it.',
#  '▁i',
#  '▁had',
#  '▁ne',
#  'ither',
#  '▁k',
#  'ith',
#  '▁nor',
#  '▁k',
#  'in',
#  '▁in',
#  '▁en',
#  'g',
#  'land',
#  ',',
#  '▁and',
#  '▁was',
#  '▁there',
#  'fore',
#  '▁as',
#  '▁fre',
#  'e',
#  '▁as',
#  '▁a',
#  'ir',
#  '--',
#  'or',
#  '▁as',
#  '▁fre',
#  'e',
#  '▁as',
#  '▁an',
#  '▁inc',
#  'ome',
#  '▁of',
#  '▁e',
#  'le',
#  'ven',
#  '▁sh',
#  'ill',
#  'ings',
#  '▁and',
#  '▁s',
#  'i',
#  'x',
#  'p',
#  'ence',
#  '▁a',
#  '▁day',
#  '▁will',
#  '▁per',
#  'm',
#  'it',
#  '▁a',
#  '▁man',
#  '▁to',
#  '▁be',
#  '.',
#  '▁under',
#  '▁such',
#  '▁c',
#  'ir',
#  'c',
#  'um',
#  'st',
#  'anc',
#  'es,',
#  '▁i',
#  '▁n',
#  'at',
#  'ur',
#  'ally',
#  '▁g',
#  'ra',
#  'v',
#  'it',
#  ...]

# %%
[t for t in freq if len(t[0]) > 1][:30]
# Out:
# [('▁the', 2504),
#  ('▁and', 1321),
#  ('▁of', 1216),
#  ('▁to', 1155),
#  ('▁a', 1070),
#  ('▁he', 856),
#  ('▁i', 855),
#  ('ed', 843),
#  ('▁in', 790),
#  ('▁was', 654),
#  ('▁his', 653),
#  ('▁that', 644),
#  ('ing', 609),
#  ('▁had', 476),
#  ('▁it', 450),
#  ('er', 410),
#  ('▁you', 408),
#  ('▁as', 379),
#  ('▁for', 358),
#  ('▁p', 339),
#  ('▁with', 337),
#  ('▁at', 320),
#  ('▁be', 319),
#  ('▁which', 315),
#  (',"', 300),
#  ('es', 298),
#  ('▁is', 297),
#  ('in', 295),
#  ('▁my', 295),
#  ('ar', 284)]
